# %%
import pandas as pd
import yfinance as yf

# %%
pip install --upgrade yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
symbol = "MASPTOP50.NS"
start = "2020-01-01"
end = "2025-07-16"

# %%
df = yf.download(symbol, start=start, end=end, interval="1d", progress=False)
df
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_5232\4086682162.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(symbol, start=start, end=end, interval="1d", progress=False)
# Price             Close         High          Low         Open       Volume
# Ticker     MASPTOP50.NS MASPTOP50.NS MASPTOP50.NS MASPTOP50.NS MASPTOP50.NS
# Date
# 2021-09-24    28.040001    28.320000    27.650000    28.219999       486265
# 2021-09-27    28.280001    28.750000    28.049999    28.600000       172502
# 2021-09-28    27.990000    30.100000    27.900000    28.549999       526085
# 2021-09-29    27.719999    28.940001    27.299999    28.940001       134730
# 2021-09-30    27.809999    28.549999    27.700001    28.549999       464066
# ...                 ...          ...          ...          ...          ...
# 2025-07-09    60.259998    60.259998    58.799999    59.889999       839268
# ...

# %%
df.to_csv("masptop50.csv")
